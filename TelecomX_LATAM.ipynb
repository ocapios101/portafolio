# %% [markdown]
# <a href="https://colab.research.google.com/github/ocapios101/portafolio/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbformat
import pandas as pd

# %%
notebook_path = "/mnt/data/TelecomX_LATAM.ipynb"
with open(notebook_path, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# %%
df.to_csv("TelecomX_LATAM.csv", index=False)

# %%
import pandas as pd

# %%
ruta_archivo = '/content/TelecomX_LATAM.csv'
df = pd.read_csv(ruta_archivo)

# %%
print(df.head())
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
print(df.columns)
# Out:
# Index(['{'], dtype='object')

# %%
if 'Churn' in df.columns:
    col_churn = 'Churn'
elif 'Evasion' in df.columns:
    col_churn = 'Evasion'
elif 'Exited' in df.columns:
    col_churn = 'Exited'
else:
    col_churn = None
    print("No se encontró columna obvia de evasión")

print(f"Columna de evasión detectada: {col_churn}")
# Out:
# No se encontró columna obvia de evasión
# Columna de evasión detectada: None

# %%
print(df.columns)
# Out:
# Index(['{'], dtype='object')

# %%
for col in df.columns:
    if 'churn' in col.lower() or 'exit' in col.lower() or 'leave' in col.lower() or 'attrition' in col.lower() or 'active' in col.lower():
        print(col)

# %%
print(df.head(10))
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN
# 8 NaN
# 9 NaN

# %%
import pandas as pd

ruta_archivo = '/content/TelecomX_LATAM.csv'
df = pd.read_csv(ruta_archivo)

# Mostrar columnas
print("Columnas en el dataset:")
print(df.columns)

# Mostrar primeras 10 filas para ver ejemplos
print("\nPrimeras 10 filas:")
print(df.head(10))
# Out:
# Columnas en el dataset:
# Index(['{'], dtype='object')
#
# Primeras 10 filas:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN
# 8 NaN
# 9 NaN

# %%
print("Número de filas:", len(df))
print("Número de columnas:", len(df.columns))
print(df.columns)
print(df.head())
# Out:
# Número de filas: 89
# Número de columnas: 1
# Index(['{'], dtype='object')
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
df = pd.read_csv(ruta_archivo, sep=';')
print(df.head())
print(df.columns)
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# Index(['{'], dtype='object')

# %%
df = pd.read_csv(ruta_archivo, sep='\t')
print(df.head())
print(df.columns)
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# Index(['{'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta_archivo = '/content/TelecomX_LATAM.csv'
df = pd.read_csv(ruta_archivo, sep=';')

# %%
print(df.head())
print(df.columns)
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# Index(['{'], dtype='object')

# %%
for col in df.columns:
    if 'churn' in col.lower() or 'exit' in col.lower() or 'leave' in col.lower() or 'attrition' in col.lower() or 'active' in col.lower():
        print(col)

# %%
print(df.columns)
# Out:
# Index(['{'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['{'], dtype='object')

# %%
col_churn = 'Churn'

# %%
for col in df.columns:
    if any(keyword in col.lower() for keyword in ['churn', 'exit', 'leave', 'attrition', 'active']):
        print(col)

# %%
import pandas as pd

# %%
ruta_archivo = '/content/TelecomX_LATAM.csv'

# %%
df = pd.read_csv(ruta_archivo, sep=';')
print(df.head())
print(df.columns)
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# Index(['{'], dtype='object')

# %%
ruta_archivo = '/content/TelecomX_LATAM.csv'

with open(ruta_archivo, 'r', encoding='utf-8') as f:
    for i in range(10):
        print(f.readline())
# Out:
# {
#
# ""
#
# ""
#
# ""
#
# ""
#
# ""
#
# ""
#
# ""
#
# ""
#
# ""

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
df = pd.read_csv("TelecomX_LATAM.csv")  # Asegúrate de tener el archivo cargado en tu entorno
df.head()
# Out:
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
df.isnull().sum()
# Out:
# {    89
# dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Churn", data=df)
plt.title("Distribución de Evasión de Clientes")
plt.xticks([0, 1], ["No Evasión", "Evasión"])
plt.xlabel("Churn")
plt.ylabel("Cantidad de Clientes")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-48756249.py in <cell line: 0>()
#       1 plt.figure(figsize=(6, 4))
# ----> 2 sns.countplot(x="Churn", data=df)
#       3 plt.title("Distribución de Evasión de Clientes")
#       4 plt.xticks([0, 1], ["No Evasión", "Evasión"])
#       5 plt.xlabel("Churn")
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ---> 67         super().__init__(data=data, variables=variables)
#      68
#      69         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Churn` for `x`. An entry with this name does not appear in `data`.

# %%
import pandas as pd

ruta_archivo = '/content/TelecomX_LATAM.csv'

try:
    # Intentar leer el CSV. Si tu CSV usa un separador diferente a la coma, especifícalo con 'sep='.
    # Puedes intentar diferentes separadores si no estás seguro (por ejemplo, sep=';' o sep='\t')
    df = pd.read_csv(ruta_archivo)
    print("Archivo CSV cargado exitosamente.")
    print("Columnas del DataFrame:")
    print(df.columns)
    print("\nPrimeras 10 filas:")
    print(df.head(10))

except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta especificada: {ruta_archivo}")
    print("Por favor, asegúrate de que el archivo 'TelecomX_LATAM.csv' esté en la carpeta '/content'.")
except Exception as e:
    print(f"Ocurrió un error al cargar el archivo CSV: {e}")
# Out:
# Intentando leer con separador por coma (','):
# Columnas del DataFrame (coma):
# Index(['{'], dtype='object')
#
# Primeras 5 filas (coma):
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# ------------------------------
# Intentando leer con separador por punto y coma (';'):
# Columnas del DataFrame (punto y coma):
# Index(['{'], dtype='object')
#
# Primeras 5 filas (punto y coma):
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# ------------------------------
# Intentando leer con separador por tabulación ('\t'):
# Columnas del DataFrame (tabulación):
# Index(['{'], dtype='object')
#
# Primeras 5 filas (tabulación):
#     {
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# ------------------------------

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

sns.boxplot(x="Churn", y="Soporte_tecnico", data=df, ax=axs[0, 0])
axs[0, 0].set_title("Soporte Técnico vs Churn")
axs[0, 0].set_xticklabels(["No", "Sí"])

sns.boxplot(x="Churn", y="Llamadas_reclamacion", data=df, ax=axs[0, 1])
axs[0, 1].set_title("Reclamaciones vs Churn")
axs[0, 1].set_xticklabels(["No", "Sí"])

sns.boxplot(x="Churn", y="Facturacion_mensual", data=df, ax=axs[1, 0])
axs[1, 0].set_title("Facturación vs Churn")
axs[1, 0].set_xticklabels(["No", "Sí"])

sns.boxplot(x="Churn", y="Promociones_recibidas", data=df, ax=axs[1, 1])
axs[1, 1].set_title("Promociones vs Churn")
axs[1, 1].set_xticklabels(["No", "Sí"])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2132371674.py in <cell line: 0>()
#       1 fig, axs = plt.subplots(2, 2, figsize=(12, 8))
#       2
# ----> 3 sns.boxplot(x="Churn", y="Soporte_tecnico", data=df, ax=axs[0, 0])
#       4 axs[0, 0].set_title("Soporte Técnico vs Churn")
#       5 axs[0, 0].set_xticklabels(["No", "Sí"])
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1595 ):
#    1596
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ---> 67         super().__init__(data=data, variables=variables)
#      68
#      69         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Churn` for `x`. An entry with this name does not appear in `data`.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="Internet", hue="Churn", data=df)
plt.title("Tipo de Internet vs Churn")
plt.xlabel("Internet")
plt.ylabel("Cantidad")
plt.legend(title="Churn", labels=["No", "Sí"])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1595998680.py in <cell line: 0>()
#       1 plt.figure(figsize=(8, 5))
# ----> 2 sns.countplot(x="Internet", hue="Churn", data=df)
#       3 plt.title("Tipo de Internet vs Churn")
#       4 plt.xlabel("Internet")
#       5 plt.ylabel("Cantidad")
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ---> 67         super().__init__(data=data, variables=variables)
#      68
#      69         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Internet` for `x`. An entry with this name does not appear in `data`.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="Internet", hue="Churn", data=df)
plt.title("Tipo de Internet vs Churn")
plt.xlabel("Internet")
plt.ylabel("Cantidad")
plt.legend(title="Churn", labels=["No", "Sí"])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1595998680.py in <cell line: 0>()
#       1 plt.figure(figsize=(8, 5))
# ----> 2 sns.countplot(x="Internet", hue="Churn", data=df)
#       3 plt.title("Tipo de Internet vs Churn")
#       4 plt.xlabel("Internet")
#       5 plt.ylabel("Cantidad")
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ---> 67         super().__init__(data=data, variables=variables)
#      68
#      69         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Internet` for `x`. An entry with this name does not appear in `data`.
